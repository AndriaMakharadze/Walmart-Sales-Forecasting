# %%
from google.colab import userdata
import os

GITHUB_TOKEN = userdata.get('GITHUB_TOKEN')
GITHUB_USER = "AndriaMakharadze"
REPO_NAME = "Walmart-Sales-Forecasting"

os.environ['GITHUB_TOKEN'] = GITHUB_TOKEN

# !git clone https://{GITHUB_USER}:{GITHUB_TOKEN}@github.com/{GITHUB_USER}/{REPO_NAME}.git
# %cd {REPO_NAME}
# !git config user.email "amakh23@freeuni.edu.ge"
# !git config user.name "AndriaMakharadze"
# Out:
# Cloning into 'Walmart-Sales-Forecasting'...
# ...
# /content/Walmart-Sales-Forecasting/Walmart-Sales-Forecasting

# %%
# !cp "/content/drive/MyDrive/ML FINAL/"*.ipynb ./
# !ls
# Out:
# cp: cannot stat '/content/drive/MyDrive/ML FINAL/*.ipynb': No such file or directory

# %%
# !git add .
# !git commit -m "Initial commit"
# !git push -u origin main
# Out:
# On branch main
#
# Initial commit
#
# nothing to commit (create/copy files and use "git add" to track)
# error: src refspec main does not match any
# error: failed to push some refs to 'https://github.com/AndriaMakharadze/Walmart-Sales-Forecasting.git'

# %%
# !pwd
# Out:
# /content/Walmart-Sales-Forecasting/Walmart-Sales-Forecasting

# %%
# %cd /content/Walmart-Sales-Forecasting
# !pwd
# Out:
# /content/Walmart-Sales-Forecasting
# /content/Walmart-Sales-Forecasting

# %%
# !ls -la
# Out:
# total 16
# drwxr-xr-x 4 root root 4096 Jul 12 15:59 .
# drwxr-xr-x 1 root root 4096 Jul 12 15:57 ..
# drwxr-xr-x 7 root root 4096 Jul 12 15:57 .git
# drwxr-xr-x 3 root root 4096 Jul 12 15:59 Walmart-Sales-Forecasting

# %%
# !ls -la Walmart-Sales-Forecasting/
# Out:
# total 12
# drwxr-xr-x 3 root root 4096 Jul 12 15:59 .
# drwxr-xr-x 4 root root 4096 Jul 12 15:59 ..
# drwxr-xr-x 7 root root 4096 Jul 12 15:59 .git

# %%
# !rm -rf Walmart-Sales-Forecasting
# !ls -la
# Out:
# total 12
# drwxr-xr-x 3 root root 4096 Jul 12 16:01 .
# drwxr-xr-x 1 root root 4096 Jul 12 15:57 ..
# drwxr-xr-x 7 root root 4096 Jul 12 15:57 .git

# %%
# !cp "/content/drive/MyDrive/ML FINAL/"*.ipynb ./
# !ls
# Out:
# cp: cannot stat '/content/drive/MyDrive/ML FINAL/*.ipynb': No such file or directory

# %%
# !ls "/content/drive/MyDrive/ML FINAL/"
# Out:
# ls: cannot access '/content/drive/MyDrive/ML FINAL/': No such file or directory

# %%
# !ls "/content/drive/MyDrive/"
# Out:
# ls: cannot access '/content/drive/MyDrive/': No such file or directory

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls "/content/drive/MyDrive/"
# Out:
#  20240209_153811.jpg
#  20240210_153352.jpg
#  20240210_154831.mp4
#  20240212_195037.jpg
#  20240212_195052.jpg
#  20240212_195849.jpg
#  20240213_191029.jpg
#  20240214_205304.mp4
#  20260516_165211_0001.mp4
#  Classroom
#  compare.c
#  Fizika
#  GPA-counter.xlsx
# 'III სემესტრის საგნები'
# 'II სემესტრის საგნები'
# 'IV სემესტრის საგნები'
# 'I სემესტრის საგნები'
# 'ML Final'
# 'SQL Server T-SQL Fundamentals.gdoc'
#  sufra.s
# 'VI სემესტრის საგნები'
# 'V სემესტრის საგნები'
# 'ააგეთ თურინგის მანქანა, რომელიც ქვემოთ მოცემულ ამ....gsheet'
# 'აზროვნების მათემატიკური წესი, პირველი დავალება.docx'
#  ამოცანები.xlsx
# 'ანდრია მახარაძე, 23-07-01, დავალება 4 (1).docx'
# 'ანდრია მახარაძე, 23-07-01, დავალება 4.docx'
#  ინფორმატიკა.docx
# 'ინფორმატიკა დავალება 3.docx'
# 'ინფორმატიკა დავალება 4.docx'
#  ისტორია.pptx
#  მანიფესტი.docx
#  რეფერატი.docx

# %%
# !ls "/content/drive/MyDrive/ML FINAL/"
# Out:
# ls: cannot access '/content/drive/MyDrive/ML FINAL/': No such file or directory
